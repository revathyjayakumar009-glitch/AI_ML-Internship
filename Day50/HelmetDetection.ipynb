# %% [markdown]
# # **Practical Task 2**
# Design dataset structure.

# %%
from IPython.display import Image, display
display(Image(filename=r"C:\Users\DELL\Downloads\image.png"))

# %% [markdown]
# # **Practical Task 3**
# Write a sample data.yaml.

# %% [markdown]
# path: D:\AI-ML Internship\Day50\Helmet-Dataset<br>
# train: ../train/images<br>
# val: ../valid/images<br>
# test: ../test/images<br>
#
# nc: 2<br>
# names: ['With Helmet', 'Without Helmet']

# %% [markdown]
# # **Practical Task 4**
# Write YOLO training code.

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(
    data=r"D:\AI-ML Internship\Day50\Helmet-Dataset\data.yaml",
    epochs=10,
    imgsz=320,
    batch=2,
    workers=0,
    device="cpu"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.75 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.62  Python-3.13.5 torch-2.12.0+cpu CPU (13th Gen Intel Core i5-1334U)
# ...

# %%
model = YOLO(r"D:\AI-ML Internship\Day50\runs\detect\train-2\weights\best.pt")

# %%
results = model(r"D:\AI-ML Internship\Day50\Helmet-Dataset\test\images\BikesHelmets18_png_jpg.rf.84a3bd2569cd63e920de9c89d731bd7c.jpg", save=True)
result1 = model(r"D:\AI-ML Internship\Day50\helmet1.png",save=True)
results[0].show()
result1[0].show()
# Out:
# image 1/1 D:\AI-ML Internship\Day50\Helmet-Dataset\test\images\BikesHelmets18_png_jpg.rf.84a3bd2569cd63e920de9c89d731bd7c.jpg: 320x320 2 With Helmets, 165.5ms
# Speed: 32.7ms preprocess, 165.5ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to D:\AI-ML Internship\Day50\runs\detect\predict
#
# image 1/1 D:\AI-ML Internship\Day50\helmet1.png: 224x320 3 With Helmets, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to D:\AI-ML Internship\Day50\runs\detect\predict

# %% [markdown]
# # **Practical Task 5**
# Draw the complete project workflow diagram.

# %%
display(Image(filename=r"C:\Users\DELL\Downloads\workflow.png"))
