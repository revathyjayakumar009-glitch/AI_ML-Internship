# %% [markdown]
# # **Practical Task 3**
# Create: <br>
# from ultralytics import YOLO <br>
#
# model = YOLO("yolov8n.pt") <br>
# Execute successfully.<br>

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
print("Execute successfully.")
# Out:
# ...
# Execute successfully.

# %% [markdown]
# # **Practical Task 4**
# Download any image containing: <br>
# • Person
# • Car
# • Dog
# Run object detection.

# %%
results = model([ 
    "person.jpg", 
    "Dog.jpg", 
    "car.jpg" 
], save=True)
for result in results:
    result.show()
# Out:
# 0: 640x640 1 person, 78.0ms
# 1: 640x640 1 dog, 1 horse, 78.0ms
# 2: 640x640 1 car, 78.0ms
# Speed: 10.8ms preprocess, 78.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to D:\AI-ML Internship\Day45\runs\detect\predict

# %% [markdown]
# # **Practical Task 5**
# Record detected objects and confidence values.<br>
# Example: <br>
# Person → 97% <br>
# Dog → 94% <br>
# Car → 90%<br>

# %% [markdown]
# Person  --> 91 % <br>
# Dog----> 42%<br>
# Car --->86%
