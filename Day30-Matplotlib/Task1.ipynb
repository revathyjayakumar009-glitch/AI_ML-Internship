# %% [markdown]
# # 1. What is Matplotlib?

# %% [markdown]
# Matplotlib is a popular Python library used for data visualization.
# It helps us create graphs and charts to represent data visually.
#
# Using Matplotlib, we can turn numbers and datasets into:
#
# * Line graphs
# * Bar charts
# * Pie charts
# * Histograms
# * Scatter plots
# And many more visualizations
#
# ### Why is Matplotlib Important?
# 1. Makes data easy to understand
# 2. Helps find patterns and trends
# 3. Used in Data Science, AI, and Machine Learning
# 4. Useful for reports and analysis

# %%
#Importing Matplotlib
import matplotlib.pyplot as plt
# matplotlib → Main library
# pyplot → Module used for plotting graphs
# plt → Short alias

# %%
x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Features of Matplotlib
#
# ✅ Easy to use<br>
# ✅ Creates different types of charts<br>
# ✅ Works with NumPy and Pandas<br>
# ✅ Highly customizable<br>
# ✅ Widely used in real-world projects<br>

# %% [markdown]
# # 2. Why visualization is important?

# %% [markdown]
# Data visualization is important because it helps us understand data easily and quickly using graphs and charts instead of large tables or numbers.
# #### Importance of Visualization
# **1. Easy to Understand**
#
# Charts and graphs make complex data simple and clear.<br>
#
# **2. Finds Patterns and Trends**
#
# Visualization helps identify:
#
# * Growth
# * Decline
# * Relationships
# * Repeated patterns
# **3. Better Decision Making**
#
# Visual data helps businesses and analysts make faster and smarter decisions.
#
# **4. Saves Time**
#
# Instead of reading thousands of numbers, a graph explains data in seconds.
#
# **5. Improves Presentation**
#
# Graphs make reports and presentations more attractive and professional.
#
# **6. Detects Errors or Outliers**
#
# Visualization helps spot unusual values or mistakes in datasets.
# #### Common Uses
# 1. Business reports
# 2. AI & Machine Learning
# 3. Weather forecasting
# 4. Stock market analysis
# 5. Student performance analysis

# %% [markdown]
# # 3. What is plot?

# %% [markdown]
# A plot is a graphical representation of data using points, lines, bars, or shapes.
#
# In Matplotlib, plots are used to visualize and understand data easily.
# #### Purpose of a Plot
# * Show relationships between data
# * Compare values
# * Identify trends and patterns
# * Present data visually
# ### Types of Plots in Matplotlib
#
# | Plot Type    | Use                |
# | ------------ | ------------------ |
# | Line Plot    | Show trends        |
# | Bar Plot     | Compare categories |
# | Pie Chart    | Show percentages   |
# | Histogram    | Show distribution  |
# | Scatter Plot | Show relationships |

# %% [markdown]
# # 4. Difference between X-axis and Y-axis

# %% [markdown]
# In graphs and plots, two lines are used to represent data:
#
# X-axis → Horizontal line<br>
# Y-axis → Vertical line<br>
# **X-axis**<br>
# Runs from left to right<br>
# Represents the independent variable<br>
# Usually shows categories, time, or input values<br>
# **Y-axis**<br>
# Runs from bottom to top<br>
# Represents the dependent variable<br>
# Usually shows measured values or output<br>
# ### Comparison Table
# | X-axis             | Y-axis                     |
# | ------------------ | -------------------------- |
# | Horizontal line    | Vertical line              |
# | Independent values | Dependent values           |
# | Left to right      | Bottom to top              |
# | Usually input data | Usually output/result data |

# %% [markdown]
# ### 5. Why graphs are important in AI?

# %% [markdown]
# Graphs are very important in Artificial Intelligence (AI) because they help visualize, analyze, and understand data clearly.
#
# AI works with large amounts of data, and graphs make that data easier to study.
# ### Importance of Graphs in AI
# **1. Understand Data Easily**
#
# Graphs convert complex data into simple visual form.<br>
#
# **2. Identify Patterns**
#
# AI models learn from patterns, and graphs help detect:
#
# * Trends
# * Relationships
# * Behaviors<br>
# **3. Analyze Model Performance**
#
# Graphs help compare:
#
# * Accuracy
# * Loss
# * Predictions
# * Errors<br>
# **4. Detect Outliers**
#
# Visualization helps find unusual or incorrect data values.<br>
#
# **5. Improve Decision Making**
#
# Graphs help data scientists make better AI decisions based on insights.
