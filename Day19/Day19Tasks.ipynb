# %% [markdown]
# **Task 2: Arithmetic Practice**
# 1. Add two arrays
# 2. Multiply arrays
# 3. Divide arrays

# %%
import numpy as np

# %%
a = np.array([2,5,8,9,4])
b = np.array([1,3,5,8,3])
print("Add two arrays:",a+b)
print("Multyply arrays:",a*b)
print("Divide arrays:",a/b)
# Out:
# Add two arrays: [ 3  8 13 17  7]
# Multyply arrays: [ 2 15 40 72 12]
# Divide arrays: [2.         1.66666667 1.6        1.125      1.33333333]

# %% [markdown]
# **Task 3: Scalar Operations**
# 1. Add constant to array
# 2. Multiply array
# 3. Subtract constant

# %%
print("Add constant to array:",a+10)
print("Multiply array:",b*10)
print("Subtract constant:",a-3)
# Out:
# Add constant to array: [12 15 18 19 14]
# Multiply array: [10 30 50 80 30]
# Subtract constant: [-1  2  5  6  1]

# %% [markdown]
# **Task 4: Math Functions**
# 1. Find square root
# 2. Find log values
# 3. Round values

# %%
print("Square root:",np.sqrt(a))
c=np.log(a)
print("Log values:",c)
print("Round values:",np.round(c,2))
# Out:
# Square root: [1.41421356 2.23606798 2.82842712 3.         2.        ]
# Log values: [0.69314718 1.60943791 2.07944154 2.19722458 1.38629436]
# Round values: [0.69 1.61 2.08 2.2  1.39]

# %% [markdown]
# **Task 5: Aggregation**
# 1. Find sum
# 2. Find mean
# 3. Find max and min

# %%
print("sum:",np.sum(a))
print("mean:",np.mean(a))
print("max:",np.max(a))
print("min:",np.min(a))
# Out:
# sum: 28
# mean: 5.6
# max: 9
# min: 2

# %% [markdown]
# **Task 6: Axis Practice**
# 1. Row-wise sum
# 2. Column-wise sum

# %%
a=np.array([[2,3,4],
           [6,8,10]])

# %%
print("Row wise sum:",np.sum(a,axis=1))
# Out:
# Row wise sum: [ 9 24]

# %%
print("Column-wise sum:",np.sum(a,axis=0))
# Out:
# Column-wise sum: [ 8 11 14]

# %% [markdown]
# **Task 7: Filtering**
# 1. Filter values > 20
# 2. Filter even numbers

# %%
arr=np.array([5,8,10,20,25,35,18,26])

# %%
print("Filter values:",arr[arr>20])
# Out:
# Filter values: [25 35 26]

# %%
print("Even numbers:",arr[arr % 2 ==0])
# Out:
# Even numbers: [ 8 10 20 18 26]
