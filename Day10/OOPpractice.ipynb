# %%
# create a class

class my_details:
    name = "anu"
    color ="green"

# %%
# create an object

obj1 = my_details()

obj1.name
# Out:
# 'anu'

# %%
obj2 = my_details()
obj2.name
# Out:
# 'anu'

# %%
print(obj2.name)
print(obj1.color)
# Out:
# anu
# green

# %%
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age


p1 = person("Roja",20)

print(p1.name)

p2 = person("Harshan",25)

print(p2.name)
print(p1.age)
# Out:
# Roja
# Harshan
# 20
