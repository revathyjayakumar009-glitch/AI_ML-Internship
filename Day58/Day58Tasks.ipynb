# %% [markdown]
# # **Practical Task 1**
# Draw the chatbot architecture diagram.

# %%
                     +------------------+
                     |      User        |
                     +------------------+
                              |
                              v
                     +------------------+
                     |  User Interface  |
                     | (Web/App/Voice)  |
                     +------------------+
                              |
                              v
                     +------------------+
                     | Input Processing |
                     | (Text/Voice)     |
                     +------------------+
                              |
                              v
                     +------------------+
                     |       NLP        |
                     | Intent & Entity  |
                     | Recognition      |
                     +------------------+
                              |
                              v
                     +------------------+
                     | Dialogue Manager |
                     +------------------+
                              |
                +-------------+-------------+
                |                           |
                v                           v
      +------------------+        +------------------+
      | Knowledge Base   |        | Database / APIs  |
      | (FAQs, Rules)    |        | External Data    |
      +------------------+        +------------------+
                \                           /
                 \                         /
                  \                       /
                   v                     v
                   +----------------------+
                   | Response Generation  |
                   +----------------------+
                              |
                              v
                     +------------------+
                     |   Chatbot Reply  |
                     +------------------+
                              |
                              v
                     +------------------+
                     |       User       |
                     +------------------+
# Out:
#   File <string>:32
#     +------------------+        +------------------+
#                                                     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # **Practical Task 2**
# List five websites or applications that use chatbots.

# %% [markdown]
# | **Website/Application** | **Purpose of the Chatbot**                                                      |
# | ----------------------- | ------------------------------------------------------------------------------- |
# | **Amazon**              | Assists customers with orders, returns, and product inquiries.                  |
# | **Flipkart**            | Provides customer support, order tracking, and shopping assistance.             |
# | **HDFC Bank**           | Helps users with banking services, account information, and FAQs.               |
# | **Swiggy**              | Supports food order tracking, delivery updates, and customer service.           |
# | **Duolingo**            | Uses AI chatbots to help users practice conversations while learning languages. |

# %% [markdown]
# # **Practical Task 3**
# Write five customer questions and identify their intents. <br>
# Example: <br>
# User Message Intent <br>
# Where is my order? Track Order <br>
# I forgot my password Password Reset

# %% [markdown]
# | **User Message**                    | **Intent**               |
# | ----------------------------------- | ------------------------ |
# | Where is my order?                  | Track Order              |
# | I forgot my password.               | Password Reset           |
# | What are your business hours?       | Business Hours Inquiry   |
# | I want to cancel my order.          | Cancel Order             |
# | How can I contact customer support? | Contact Customer Support |

# %% [markdown]
# # **Practical Task 4**
# Create a simple conversation flow for a banking chatbot.

# %%
                Start
                  │
                  ▼
      Welcome to ABC Bank!
How can I help you today?
                  │
      ┌───────────┼───────────┐
      ▼           ▼           ▼
 Check Balance  Transfer Money  Report Lost Card
      │           │             │
      ▼           ▼             ▼
 Ask Account   Ask Recipient   Confirm Card Details
   Number       & Amount        │
      │           │             ▼
      ▼           ▼      Block Card Request
 Verify User   Verify User       │
      │           │             ▼
      ▼           ▼      Card Blocked
 Show Balance  Transfer Successful
      │           │
      └───────┬───┘
              ▼
     Anything Else? (Yes/No)
          │           │
         Yes         No
          │           │
          ▼           ▼
      Main Menu     Thank You!
                    Have a Nice Day.
# Out:
#   File <string>:9
#     Check Balance  Transfer Money  Report Lost Card
#                                                    ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # **Practical Task 5**
# Compare Rule-Based and AI-Based chatbots in a table.
