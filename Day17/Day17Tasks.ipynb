# %% [markdown]
# **Task 2: Math Practice**
# 1. Find square root
# 2. Find power
# 3. Round numbers
# 4. Use π value

# %%
import math

# %%
#Find power
print("Square Root:",math.sqrt(121))
#Find Power
print("Power :",math.pow(3,2))
#Round Numbers
print("Round Numbers:",math.ceil(4.55))
print("Round Numbers:",math.floor(4.55))
#Use  π value
print(" π value:",math.pi)
# Out:
# Square Root: 11.0
# Power : 9.0
# Round Numbers: 5
# Round Numbers: 4
#  π value: 3.141592653589793

# %% [markdown]
#  **Task 3: Random Practice**
# 1. Generate random number
# 2. Pick random element
# 3. Generate list of random numbers

# %%
import random

# %%
#Generate random number
print(random.randint(1, 10)) 
#Pick random element
fruits = ["apple", "banana", "mango", "orange"]
print(random.choice(fruits))
#Generate list of random numbers
numbers = []
for i in range(5):
    numbers.append(random.randint(1, 100))

print(numbers)
# Out:
# 8
# mango
# [99, 53, 4, 16, 97]

# %% [markdown]
# **Task 4: Datetime Practice**
# 1. Print current date
# 2. Format date
# 3. Extract year, month

# %%
import datetime

# %%
#Print Current date
now = datetime.datetime.now() 
print(now.date())
#Format date
print(now.strftime("%Y-%m-%d"))
#Extract Year,month
print(now.year)    
print(now.month)
# Out:
# 2026-04-28
# 2026-04-28
# 2026
# 4

# %% [markdown]
# **Task 5: Visualization**
# 1. Create line graph
# 2. Create bar chart
# 3. Plot student marks

# %%
import matplotlib.pyplot as plt

# %%
#Create line graph
x = [1, 2, 3]
y = [4, 5, 6]

plt.plot(x, y)
plt.title("Line chart")
plt.show()

# %%
#Create bar chart
subjects = ["Math", "Science", "English"]
marks = [85, 90, 78]

plt.bar(subjects, marks)
plt.title("Bar Chart")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
#plot student marks
students = ["A", "B", "C", "D"]
marks = [75, 88, 92, 80]

plt.plot(students, marks, marker='o')
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()
